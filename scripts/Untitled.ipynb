# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('../data/statcast_2025.parquet')

# %%
df
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1993         FF 2025-09-28           95.7          -2.15           5.21
# 2041         FF 2025-09-28           95.1          -1.91            5.1
# 2139         FF 2025-09-28           95.4          -1.99           5.22
# 2224         SL 2025-09-28           84.8          -2.33           4.72
# 2305         SL 2025-09-28           85.3          -2.26           4.85
# ...         ...        ...            ...            ...            ...
# 2767       None 2025-03-20           <NA>           <NA>           <NA>
# 2901       None 2025-03-20           <NA>           <NA>           <NA>
# 3072       None 2025-03-20           <NA>           <NA>           <NA>
# 3104       None 2025-03-20           <NA>           <NA>           <NA>
# 3298       None 2025-03-20           <NA>           <NA>           <NA>
#
#          player_name  batter  pitcher     events      description  spin_dir  \
# ...

# %%
plt.scatter(df[df['pitch_type'] == 'CU']['pfx_x'],df[df['pitch_type'] == 'CU']['pfx_z'])
